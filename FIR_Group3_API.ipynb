# %%
import tweepy
import configparser
import pandas as pd

# %%
# read configs
config = configparser.ConfigParser()
config.read('config.ini')

api_key = config['twitter']['api_key']
api_key_secret = config['twitter']['api_key_secret']

access_token = config['twitter']['access_token']
access_token_secret = config['twitter']['access_token_secret']

# %%
# authentication
auth = tweepy.OAuthHandler(api_key, api_key_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

# %%
user = 'elonmusk'
limit=2500

tweets = tweepy.Cursor(api.user_timeline, screen_name=user, count=200, tweet_mode='extended').items(limit)

# tweets = api.user_timeline(screen_name=user, count=limit, tweet_mode='extended')

# create DataFrame
columns = ['User', 'Tweet', 'time']
data = []

for tweet in tweets:
    data.append([tweet.user.screen_name, tweet.full_text, tweet.created_at])

df = pd.DataFrame(data, columns=columns)

print(df)
# Out:
#         User                                              Tweet  \
# 0   elonmusk                                       @pmarca Yeah
# 1   elonmusk                           @engineers_feed Hardcore
# 2   elonmusk  @WholeMarsBlog They have no idea how hard FSD ...
# 3   elonmusk  Thank you for the offer, but such excellent tr...
# 4   elonmusk                                        @prosmoon 🤣
# 5   elonmusk  Telegram post by Ramzan Kadyrov, head of Chech...
# 6   elonmusk                   @Astra @SpaceflightInc Congrats!
# 7   elonmusk            @Teslarati @ResidentSponge 💫 Starlink 💫
# 8   elonmusk               @dogeofficialceo @EvaFoxU @Rogozin 🎯
# 9   elonmusk          @EvaFoxU @Rogozin https://t.co/44fQNWBEdx
# 10  elonmusk  @Rogozin And … um … [flicks wrist] we should f...
# 11  elonmusk           @JaneidyEve @GailAlfarATX @Rogozin Ok :)
# 12  elonmusk                @Rogozin He can even bring his bear
# 13  elonmusk  @Rogozin I see you are a tough negotiator!\n\n...
# ...

# %%
df
# Out:
#         User                                              Tweet  \
# 0   elonmusk                                       @pmarca Yeah
# 1   elonmusk                           @engineers_feed Hardcore
# 2   elonmusk  @WholeMarsBlog They have no idea how hard FSD ...
# 3   elonmusk  Thank you for the offer, but such excellent tr...
# 4   elonmusk                                        @prosmoon 🤣
# 5   elonmusk  Telegram post by Ramzan Kadyrov, head of Chech...
# 6   elonmusk                   @Astra @SpaceflightInc Congrats!
# 7   elonmusk            @Teslarati @ResidentSponge 💫 Starlink 💫
# 8   elonmusk               @dogeofficialceo @EvaFoxU @Rogozin 🎯
# 9   elonmusk          @EvaFoxU @Rogozin https://t.co/44fQNWBEdx
# 10  elonmusk  @Rogozin And … um … [flicks wrist] we should f...
# 11  elonmusk           @JaneidyEve @GailAlfarATX @Rogozin Ok :)
# 12  elonmusk                @Rogozin He can even bring his bear
# 13  elonmusk  @Rogozin I see you are a tough negotiator!\n\n...
# ...

# %%
# df.to_csv('elonmusk_timeline.csv')

# %%
keywords = '@elonmusk'  # for user

limit=2500

tweets = tweepy.Cursor(api.search_tweets, q=keywords, count=100, tweet_mode='extended').items(limit)

columns = ['User', 'Tweet', 'Time']
data = []

for tweet in tweets:
    data.append([tweet.user.screen_name, tweet.full_text, tweet.created_at])

search_df = pd.DataFrame(data, columns=columns)

# %%
# search_df.to_csv('elonmusk_data.csv')

# %%
keywords = '@bitcoin'  # for user

limit=2500

tweets = tweepy.Cursor(api.search_tweets, q=keywords, count=100, tweet_mode='extended').items(limit)

columns = ['User', 'Tweet', 'Time']
data = []

for tweet in tweets:
    data.append([tweet.user.screen_name, tweet.full_text, tweet.created_at])

bitcoin_df = pd.DataFrame(data, columns=columns)

# %%
bitcoin_df
# Out:
#                  User                                              Tweet  \
# 0        CheffWallets  RT @Robast7: @CRYPTO takes a deep dive into @B...
# 1             Robast7  @CRYPTO takes a deep dive into @BITCOIN 🌊\n\nR...
# 2     carterlandon300  RT @ReggieMiddleton: Below, a table of content...
# 3         BlacDonalds  RT @ReggieMiddleton: Below, a table of content...
# 4             Vixx285  March 14 🐋 The third largest whale adds 87 BTC...
# ...               ...                                                ...
# 2495      asna_hashim  RT @Bitcoin: You can wish. https://t.co/AJTXRr...
# 2496      asna_hashim  RT @Bitcoin: 'Institutions are coming!'\n'What...
# 2497      asna_hashim               RT @Bitcoin: https://t.co/WXsu6eePEg
# 2498      asna_hashim               RT @Bitcoin: https://t.co/OPMss2tktd
# 2499      asna_hashim  RT @Bitcoin: What happens when the liquidity g...
#
#                           Time
# 0    2022-03-16 16:43:50+00:00
# ...

# %%
# bitcoin_df.to_csv('bitcoin_data.csv')

# %%
keywords = '@dogecoin'  # for user

limit=2500

tweets = tweepy.Cursor(api.search_tweets, q=keywords, count=100, tweet_mode='extended').items(limit)

columns = ['User', 'Tweet', 'Time']
data = []

for tweet in tweets:
    data.append([tweet.user.screen_name, tweet.full_text, tweet.created_at])

dogecoin_df = pd.DataFrame(data, columns=columns)

# %%
# dogecoin_df.to_csv('dogecoin_data.csv')

# %%
dogecoin_df
# Out:
#                  User                                              Tweet  \
# 0      Durgesh8881756  RT @BlackHoleDAO_: BHO+DOGE+SHIB jointly issue...
# 1     NguyenN46834407  RT @BlackHoleDAO_: BHO+DOGE+SHIB jointly issue...
# 2         PlayFun0401  RT @BitCloutCat: 这个老板整理相册不小心翻出差不多3亿@dogecoin ，...
# 3          k_kadirkay  RT @Okex_Brasil: 📈 Compre #BabyDoge e outras #...
# 4     EricVelezFerre1  RT @BlackHoleDAO_: BHO+DOGE+SHIB jointly issue...
# ...               ...                                                ...
# 2495       thangmuoij  RT @BlackHoleDAO_: BHO+DOGE+SHIB jointly issue...
# 2496    morens_crypto  @Ivy67323669 @dogecoin @CornDoges https://t.co...
# 2497  HoangVa26832420  RT @BlackHoleDAO_: BHO+DOGE+SHIB jointly issue...
# 2498    morens_crypto  RT @morens_crypto: @Ivy67323669 @dogecoin @Cor...
# 2499        vigamingt  RT @BlackHoleDAO_: BHO+DOGE+SHIB jointly issue...
#
#                           Time
# 0    2022-03-16 16:46:00+00:00
# ...

# %%
for i in dogecoin_df['Tweet']:
#     print(i)
#     add sentimental analysis here
# Out:
# RT @BlackHoleDAO_: BHO+DOGE+SHIB jointly issued $1,000,000 #airdrop!
# 100% chance to win!💸💸💸💸🎁🎁🎁🎁
# 💵$1,000,000,000BHO
# 💵$120,000,000SHIB
# 💵$2…
# RT @BlackHoleDAO_: BHO+DOGE+SHIB jointly issued $1,000,000 #airdrop!
# 100% chance to win!💸💸💸💸🎁🎁🎁🎁
# 💵$1,000,000,000BHO
# 💵$120,000,000SHIB
# 💵$2…
# RT @BitCloutCat: 这个老板整理相册不小心翻出差不多3亿@dogecoin ，还给群里的人空投了，那么问题来了，为什么我没在那个群。 https://t.co/5nA4ZNz4MA
# RT @Okex_Brasil: 📈 Compre #BabyDoge e outras #memecoins na #OKX! 🐶🐕🦴
#
# #BABYDOGE @BabyDogeCoin
# #DOGE @dogecoin
# #ELON @DogelonMars
# #KISHU @In…
# RT @BlackHoleDAO_: BHO+DOGE+SHIB jointly issued $1,000,000 #airdrop!
# 100% chance to win!💸💸💸💸🎁🎁🎁🎁
# 💵$1,000,000,000BHO
# 💵$120,000,000SHIB
# 💵$2…
# RT @Okex_Brasil: 📈 Compre #BabyDoge e outras #memecoins na #OKX! 🐶🐕🦴
#
# #BABYDOGE @BabyDogeCoin
# #DOGE @dogecoin
# #ELON @DogelonMars
# #KISHU @In…
# @Okex_Brasil @frame_hz @BabyDogeCoin @dogecoin @DogelonMars @InuKishu @Shibtoken @PolyDoge @samoyedcoin @BabyDogeArmy_BR #babydogecoin #babydoge
# ...
